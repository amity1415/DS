# %% [markdown]
# # AnomalyDetection using Independent-Univariate and Multivariate Analysis#

# %%
#kmeans

# prob/distance lines - circular in shape.
#simple
##----------------------##

#indp-univariates

# Normal probability; Gaussian; Assumptions-Normal, independence (<corr); 
# faster - why - less comptation, no distance calculation needed.
# prob lines - elliptical but arallel to axis
# a little difficult
##----------------------##

#multi-gaussian

# no indp assumtion. Assumption - Normal; elliptical shape, but can be obligue
# a lot difficult - math involved
##----------------------##

# %% [markdown]
# ##### Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import math

# %%
# Special Thanks to https://github.com/abhishek-Kumar009/Machine-Learning/tree/master/AnomalyDetectionScratch
# for the dataset and parent code.

# Please note: This code is an edited version by Deepesh Wadhwani. He corrected some errors in evaluation the 
# multivariate gaussian probability distribution. Also Arranged the code to facilitate explanationation of the algorithm.

# %%
# import dataset as:
# 60% TRAIN SET = X
# 20% VAL Set inclusing half of positive examples = Xval, y_val - calculate the hyperparametwes
# 20% as TEST SET including othr half of positive examples = Xtest, ytest


dataset = sio.loadmat('anomalyData.mat')
X = dataset['X']

Xval = dataset['Xval']
y_val = dataset['yval']


# df = pd.read_csv('filename.csv')

# %%
print(X.shape)
# Out:
# (307, 2)

# %%
plt.scatter(X[:, 0], X[:, 1], marker = ".")
plt.xlabel('X1')
plt.ylabel('X2')
# Out:
# Text(0, 0.5, 'X2')

# %%
#outliers = 6 - in what set? - train set

# %%
def estimate_Gaussian(X):
    n = np.size(X, 1) #number of variables
    m = np.size(X, 0) #number of data points
    mu = np.zeros((n, 1)) #creating a zero array to fill it later with desired calculation
    sigma2 = np.zeros((n, 1))
    
    mu = np.reshape((1/m)*np.sum(X, 0), (1, n))
    sigma2 = np.reshape((1/m)*np.sum(np.power((X - mu),2), 0),(1, n))
    
    return mu, sigma2

# %%
def estimate_I_univariate_Probability(X, mu, sigma2):
    # estimation of independent univariate probabilities. The function multiplies all the Independent probabilaties
    # to give the final estimated probability of data point.
    
    n = np.size(X, 1)
    m = np.size(X, 0)
      

    sigma2 = np.diag(sigma2[0, :])
    
    X = X - mu
    pi = math.pi
    
    det = np.linalg.det(sigma2)
    inv = np.linalg.inv(sigma2)
    val = np.reshape((-0.5)*np.sum(np.multiply((X@inv),X), 1),(np.size(X, 0), 1))
    
    p = np.power(2*pi, -n/2)*np.power(det, -0.5)*np.exp(val)
    
    return p

#scipy.pdf(data)

# %%
mu, sigma2 = estimate_Gaussian(X)
print('mean: ',mu,' variance: ',sigma2)
# Out:
# mean:  [[14.11222578 14.99771051]]  variance:  [[1.83263141 1.70974533]]

# %%
p_uni = estimate_I_univariate_Probability(X, mu, sigma2)
print(p_uni.shape)
# Out:
# (307, 1)

# %%
p_uni
#0.0647
# Out:
# array([[6.47082850e-02],
#        [5.03041697e-02],
#        [7.24503459e-02],
#        [5.03157451e-02],
#        [6.36849657e-02],
#        [4.24583228e-02],
#        [4.79094514e-02],
#        [3.65111476e-02],
#        [1.86657981e-02],
#        [5.06882606e-02],
#        [2.65150875e-02],
#        [8.47130185e-02],
#        [5.53118482e-02],
#        [7.20696157e-02],
#        [4.39740990e-02],
#        [7.05254661e-02],
#        [6.28238124e-03],
#        [6.45202201e-02],
#        [3.19314201e-02],
#        [5.07397326e-02],
#        [3.73145084e-02],
#        [6.71099308e-02],
#        [8.35605668e-02],
#        [5.35571729e-02],
#        [8.76881796e-02],
#        [5.29430953e-02],
#        [8.77407216e-02],
#        [4.95417100e-02],
#        [4.24129376e-02],
#        [7.54137034e-02],
#        [6.57821432e-02],
#        [6.55062518e-02],
#        [7.24227917e-02],
#        [6.57029225e-02],
#        [7.18996551e-02],
#        [5.60565776e-02],
#        [6.89732355e-02],
#        [5.25875443e-02],
#        [8.40942927e-02],
#        [8.69876312e-02],
#        [6.47407569e-02],
#        [4.42194372e-02],
#        [2.37352634e-02],
#        [3.89644526e-02],
#        [3.56946069e-02],
#        [5.83220038e-02],
#        [2.29994711e-02],
#        [7.65943681e-02],
#        [3.21847761e-02],
#        [5.78630925e-02],
#        [6.63407745e-02],
#        [7.53910796e-02],
#        [6.72341277e-02],
#        [6.42521098e-02],
#        [7.35872805e-02],
#        [6.12199799e-02],
#        [8.94762010e-02],
#        [7.86897544e-02],
#        [8.98609508e-02],
#        [8.49000815e-02],
#        [6.57829489e-02],
#        [7.21847367e-02],
#        [7.22682876e-02],
#        [8.71862113e-02],
#        [7.94024944e-02],
#        [7.20475229e-02],
#        [1.25364342e-02],
#        [5.93339213e-06],
#        [1.18120912e-23],
#        [3.98134038e-02],
#        [5.45567281e-08],
#        [4.46172062e-12],
#        [6.10718445e-05],
#        [2.91286664e-23]])

# %%
def estimate_multivariate_Gaussian(X):
    
    n = np.size(X, 1)
    m = np.size(X, 0) 
     
     
    mu = np.reshape((1/m)*np.sum(X, 0), (1, n))
    sigma2 = np.cov(X, rowvar=False)
      
    return mu, sigma2

# %%
mu_m, sigma2_m = estimate_multivariate_Gaussian(X)
print('mean: ',mu_m,' variance: ',sigma2_m)
# Out:
# mean:  [[14.11222578 14.99771051]]  variance:  [[ 1.83862041 -0.22786456]
#  [-0.22786456  1.71533273]]

# %%
def estimate_multivariate_Probability(X, mu, sigma2):
    
    n = np.size(X, 1)
    m = np.size(X, 0)
     
    X = X - mu
    pi = math.pi
    det = np.linalg.det(sigma2)
    inv = np.linalg.inv(sigma2)
    val = np.reshape((-0.5)*np.sum(np.multiply((X@inv),X), 1),(np.size(X, 0), 1))
     
    p = np.power(2*pi, -n/2)*np.power(det, -0.5)*np.exp(val)
     
    return p

# %%
p_multi = estimate_multivariate_Probability(X, mu_m, sigma2_m)
print(p_multi.shape)
# Out:
# (307, 1)

# %%
p_multi
# Out:
# array([[6.34613307e-02],
#        [4.70643205e-02],
#        [7.22245815e-02],
#        [4.68150396e-02],
#        [6.13620607e-02],
#        [4.13179675e-02],
#        [4.43670432e-02],
#        [3.27150717e-02],
#        [1.53184538e-02],
#        [5.00269407e-02],
#        [2.57188777e-02],
#        [8.49305647e-02],
#        [7.33443510e-02],
#        [7.20172575e-02],
#        [4.75967809e-02],
#        [7.22095970e-02],
#        [4.33885493e-03],
#        [6.32547543e-02],
#        [2.94421229e-02],
#        [4.88195393e-02],
#        [3.39659006e-02],
#        [6.65292547e-02],
#        [8.35010322e-02],
#        [5.71053566e-02],
#        [8.80220265e-02],
#        [4.93790543e-02],
#        [8.78927501e-02],
#        [4.61810174e-02],
#        [3.85287008e-02],
#        [7.42885935e-02],
#        [6.69380032e-02],
#        [6.76158617e-02],
#        [7.45290204e-02],
#        [6.84456723e-02],
#        [7.07605260e-02],
#        [5.49656960e-02],
#        [7.13713692e-02],
#        [5.57011469e-02],
#        [8.37131174e-02],
#        [8.74447520e-02],
#        [6.44863232e-02],
#        [4.01599324e-02],
#        [2.68251077e-02],
#        [3.49118555e-02],
#        [3.42800391e-02],
#        [5.51003707e-02],
#        [2.13292690e-02],
#        [7.75942807e-02],
#        [2.99564077e-02],
#        [5.80493218e-02],
#        [6.39631051e-02],
#        [7.39406394e-02],
#        [6.48410019e-02],
#        [6.27473601e-02],
#        [7.23875651e-02],
#        [5.88161495e-02],
#        [8.98659150e-02],
#        [7.99894898e-02],
#        [9.03172802e-02],
#        [8.56432185e-02],
#        [6.59022875e-02],
#        [7.41903618e-02],
#        [7.41190085e-02],
#        [8.72654656e-02],
#        [7.84031761e-02],
#        [7.16820057e-02],
#        [9.54150639e-03],
#        [3.41334921e-06],
#        [2.64122235e-21],
#        [3.71001796e-02],
#        [2.85710156e-07],
#        [1.34985777e-12],
#        [2.24372245e-05],
#        [9.34704878e-21]])

# %%
pval_univariate = estimate_I_univariate_Probability(Xval, *estimate_Gaussian(X))

# %%
pval_multivariate = estimate_multivariate_Probability(Xval, *estimate_multivariate_Gaussian(X))

# %%
print(pval_multivariate.size , pval_univariate.size)
# Out:
# 307 307

# %%
pval_multivariate - pval_univariate

#if the estimate was same, the difference would have been zero.
# Out:
# array([[ 1.73222897e-04],
#        [ 1.26454241e-03],
#        [-3.40470858e-03],
#        [-2.37084471e-03],
#        [ 2.33409334e-03],
#        [ 4.11613383e-03],
#        [-9.52075294e-04],
#        [ 9.26145841e-04],
#        [-2.49314578e-03],
#        [ 6.40333905e-04],
#        [-9.38785522e-04],
#        [-9.02921008e-04],
#        [ 3.51141806e-03],
#        [-3.23234581e-03],
#        [ 3.12464497e-03],
#        [-4.01567900e-03],
#        [ 3.61310398e-03],
#        [-1.18299154e-03],
#        [-9.29561329e-04],
#        [-3.85782719e-03],
#        [ 4.05676919e-04],
#        [-4.27304219e-03],
#        [ 3.61001654e-04],
#        [-6.68075478e-04],
#        [ 2.12665185e-03],
#        [ 1.20284132e-03],
#        [-4.02319646e-03],
#        [ 2.01897977e-03],
#        [-3.40893020e-03],
#        [ 5.52742590e-04],
#        [ 7.79651059e-04],
#        [ 9.51589940e-04],
#        [ 1.97583070e-03],
#        [ 4.14075009e-04],
#        [ 1.94502731e-04],
#        [ 2.61826846e-04],
#        [-1.70535649e-03],
#        [-4.04778472e-03],
#        [ 3.31367828e-04],
#        [ 5.10455475e-04],
#        [-2.78101079e-03],
#        [-2.34821088e-03],
#        [ 2.67473349e-03],
#        [ 7.18478126e-04],
#        [ 4.96330017e-04],
#        [ 2.04618848e-03],
#        [-2.92048481e-04],
#        [-1.29808961e-04],
#        [ 4.04550171e-04],
#        [-2.45652414e-03],
#        [-3.86234411e-03],
#        [ 4.44809865e-04],
#        [ 4.07399878e-04],
#        [-7.87688319e-04],
#        [-1.24240207e-03],
#        [ 2.18859604e-03],
#        [ 4.02854192e-04],
#        [ 2.42862755e-03],
#        [-8.14820858e-04],
#        [-2.39381874e-04],
#        [ 4.01208148e-04],
#        [ 6.09391102e-05],
#        [-5.12273056e-04],
#        [ 3.95749059e-03],
#        [-2.41946788e-03],
#        [ 4.08391111e-03],
#        [-1.96160686e-03],
#        [ 4.65801864e-04],
#        [-4.12367464e-03],
#        [-8.83784765e-04],
#        [-4.94691982e-04],
#        [-1.28202052e-04],
#        [-2.23049779e-03],
#        [ 1.23132038e-04],
#        [ 1.44042791e-03],
#        [ 5.19932888e-04],
#        [ 1.29746576e-03],
#        [-3.33687425e-03],
#        [-3.39215725e-03],
#        [-2.12312309e-03],
#        [ 3.78140695e-03],
#        [-3.17393706e-04],
#        [ 1.52898536e-03],
#        [ 2.79476903e-04],
#        [-5.99060059e-04],
#        [ 2.15561302e-03],
#        [-3.96764402e-03],
#        [-1.41306861e-03],
#        [ 2.18861065e-03],
#        [ 4.41610997e-04],
#        [ 1.68913885e-03],
#        [-1.75255245e-03],
#        [-8.83491565e-04],
#        [ 2.19202030e-03],
#        [-2.59815826e-03],
#        [-4.00081962e-03],
#        [-8.72259077e-04],
#        [-9.03767467e-04],
#        [-2.28235155e-04],
#        [ 1.18740406e-03],
#        [-1.55385710e-03],
#        [-6.67846152e-04],
#        [ 1.56983161e-03],
#        [ 1.58284005e-03],
#        [ 2.38744874e-03],
#        [-3.24741507e-03],
#        [-2.97168446e-03],
#        [ 4.52452131e-04],
#        [-4.26051881e-03],
#        [-2.59857769e-04],
#        [ 6.65653597e-04],
#        [-1.25184700e-03],
#        [-2.21680108e-03],
#        [-1.26027449e-03],
#        [-2.32049369e-03],
#        [ 1.36140462e-04],
#        [-1.33787129e-03],
#        [-1.16928181e-03],
#        [ 3.40528482e-04],
#        [-5.90246256e-05],
#        [-2.37230296e-04],
#        [ 3.95136788e-03],
#        [ 4.23588968e-04],
#        [-1.28596540e-03],
#        [-8.57558377e-04],
#        [ 2.52895315e-03],
#        [-3.21149724e-03],
#        [-2.32100432e-03],
#        [ 1.20647209e-03],
#        [-6.98095734e-04],
#        [ 2.27456132e-04],
#        [-2.36412625e-03],
#        [-2.72067482e-03],
#        [ 2.01525737e-03],
#        [ 4.90445138e-04],
#        [ 2.73424775e-03],
#        [-2.30315837e-03],
#        [-2.20704035e-03],
#        [-2.84440160e-03],
#        [ 1.92094838e-03],
#        [-3.12812485e-03],
#        [-1.61996388e-03],
#        [ 1.84567297e-03],
#        [-9.34794012e-04],
#        [ 1.67457120e-03],
#        [ 1.07180343e-03],
#        [ 1.85091743e-03],
#        [-1.91320134e-03],
#        [-3.46713846e-03],
#        [ 1.22413151e-03],
#        [ 8.28378348e-04],
#        [ 1.01099928e-04],
#        [-1.97091266e-03],
#        [ 3.71320585e-03],
#        [ 1.87967628e-04],
#        [ 1.81099224e-03],
#        [ 4.91710560e-04],
#        [ 6.60717215e-04],
#        [-1.35093027e-03],
#        [ 8.02729045e-04],
#        [-8.85059417e-04],
#        [-1.24146975e-03],
#        [-4.14874794e-03],
#        [-2.31567838e-03],
#        [-1.37595400e-03],
#        [-1.97596453e-03],
#        [ 1.33094461e-03],
#        [ 8.32966805e-04],
#        [-1.93512898e-03],
#        [ 3.44220081e-03],
#        [-2.78663301e-03],
#        [-3.74306674e-03],
#        [-3.66633200e-03],
#        [-3.17254973e-03],
#        [-3.12519272e-03],
#        [ 1.54360150e-03],
#        [-3.37464058e-03],
#        [-2.48802106e-03],
#        [-6.90915912e-04],
#        [-1.02539382e-03],
#        [ 4.53878969e-04],
#        [-5.92200365e-04],
#        [-3.47524762e-03],
#        [ 8.78307029e-04],
#        [ 6.50557436e-04],
#        [ 1.12247580e-04],
#        [-1.68809498e-03],
#        [ 1.28920439e-03],
#        [-3.88061779e-03],
#        [ 6.59671644e-04],
#        [-3.41506907e-03],
#        [ 5.43546365e-05],
#        [-9.29391730e-04],
#        [ 1.81928103e-04],
#        [-2.25189952e-03],
#        [ 1.23233494e-03],
#        [-4.65783310e-04],
#        [ 1.02253321e-03],
#        [ 2.89863730e-03],
#        [-4.02470670e-03],
#        [-2.52139049e-03],
#        [ 3.98874311e-03],
#        [ 1.46389515e-03],
#        [-4.17966794e-03],
#        [ 8.77383909e-04],
#        [-3.98128281e-03],
#        [-4.07297145e-03],
#        [-1.13788983e-04],
#        [ 8.71500750e-04],
#        [-3.31256837e-04],
#        [ 8.12960029e-04],
#        [-3.71464570e-03],
#        [ 2.30731392e-03],
#        [-3.28612559e-03],
#        [ 1.36495150e-03],
#        [ 4.04995462e-03],
#        [-3.73112881e-03],
#        [ 1.20594045e-03],
#        [-3.57796860e-03],
#        [ 3.62787963e-03],
#        [-4.47286800e-04],
#        [ 4.87058587e-04],
#        [ 3.41814721e-03],
#        [ 5.98238463e-04],
#        [-4.06641006e-03],
#        [-1.39967923e-03],
#        [ 1.97392306e-04],
#        [ 1.15444731e-03],
#        [ 3.80598006e-03],
#        [ 6.26268992e-04],
#        [-1.08765109e-03],
#        [-1.40208967e-03],
#        [ 1.97067886e-03],
#        [ 2.15794506e-05],
#        [-3.43275904e-03],
#        [ 5.77046710e-04],
#        [-3.87015869e-03],
#        [ 2.46380613e-04],
#        [ 7.43861880e-04],
#        [-2.78422210e-03],
#        [ 2.92405961e-05],
#        [-2.83756560e-03],
#        [-2.73516349e-03],
#        [ 4.03565812e-04],
#        [ 4.33308318e-04],
#        [-3.16703859e-03],
#        [-1.95985611e-04],
#        [ 3.69585610e-03],
#        [-3.55580996e-03],
#        [ 1.43691024e-03],
#        [ 2.89250245e-03],
#        [ 1.90128842e-03],
#        [-4.02528352e-03],
#        [-4.17772706e-04],
#        [-3.44406740e-03],
#        [ 1.28166864e-03],
#        [-1.17809483e-03],
#        [-4.02172617e-03],
#        [ 4.83025116e-05],
#        [-3.55632406e-03],
#        [ 5.67175266e-04],
#        [-3.04079457e-03],
#        [-1.27266231e-03],
#        [ 2.03313214e-03],
#        [ 8.27653665e-04],
#        [ 1.88250860e-03],
#        [ 2.32798153e-03],
#        [-2.09891853e-03],
#        [-4.07160970e-04],
#        [ 1.13395907e-03],
#        [ 2.02750703e-03],
#        [-2.65783590e-03],
#        [-3.08842329e-04],
#        [-2.45411252e-04],
#        [-3.77067784e-03],
#        [-3.18587814e-03],
#        [-3.16720256e-03],
#        [-2.41901088e-03],
#        [-1.55548144e-03],
#        [-7.66592128e-04],
#        [-1.81814511e-03],
#        [-4.05617399e-03],
#        [-2.86011720e-03],
#        [ 2.66691218e-03],
#        [ 1.83537703e-03],
#        [-1.82474068e-03],
#        [-1.82720287e-03],
#        [-3.59851499e-03],
#        [-4.62127004e-05],
#        [ 8.44336964e-04],
#        [ 6.40965480e-04],
#        [-3.35748554e-04],
#        [-2.52394060e-03],
#        [-1.85301712e-03],
#        [-2.04419573e-04],
#        [-2.89787686e-03],
#        [-6.67489424e-04],
#        [-8.08252219e-04],
#        [ 2.69023856e-03],
#        [-2.38208019e-03],
#        [ 8.59784744e-07],
#        [ 1.07915445e-05],
#        [-4.51315855e-36],
#        [-5.58355711e-32],
#        [ 1.46873566e-05],
#        [-4.14409450e-11],
#        [ 1.22094627e-05]])

# %%
print((y_val==1).sum(), " ", (y_val==0).sum())
# Out:
# 9   298

# %%
def selectThreshHold(yval, pval):
    #finding epsilon for which F1 score is minimum.
    
    F1 = 0
    bestF1 = 0
    bestEpsilon = 0
    
    stepsize = (np.max(pval) - np.min(pval))/1000
        
    epsVec = np.arange(np.min(pval), np.max(pval), stepsize)
    noe = len(epsVec) #creating a list of epsilon values we should check to find which has min F1 score
    
    for eps in range(noe):
        epsilon = epsVec[eps]
        pred = (pval < epsilon)
        prec, rec = 0,0
        tp,fp,fn = 0,0,0
        
        try:
            for i in range(np.size(pval,0)):
                if pred[i] == 1 and yval[i] == 1:
                    tp+=1
                elif pred[i] == 1 and yval[i] == 0:
                    fp+=1
                elif pred[i] == 0 and yval[i] == 1:
                    fn+=1
            prec = tp/(tp + fp)
            rec = tp/(tp + fn)
            F1 = 2*prec*rec/(prec + rec)
            if F1 > bestF1:
                bestF1 = F1
                bestEpsilon = epsilon
        except ZeroDivisionError:
            print('Warning dividing by zero!!')          
       
    return bestF1, bestEpsilon

# %%
F1_uni, epsilon_uni = selectThreshHold(y_val, pval_univariate)
print('For Univariate Epsilon and F1 are:',epsilon_uni, F1_uni)
# Out:
# Warning dividing by zero!!
# For Univariate Epsilon and F1 are: 8.990852779269493e-05 0.8750000000000001

# %%
F1_multi, epsilon_multi = selectThreshHold(y_val, pval_multivariate)
print('For Multivariate Epsilon and F1 are:',epsilon_multi, F1_multi)
# Out:
# Warning dividing by zero!!
# For Multivariate Epsilon and F1 are: 9.036240676156382e-05 0.8750000000000001

# %%
def findIndices(binVec):
    l = []
    for i in range(len(binVec)):
        if binVec[i] == 1:
            l.append(i)
    return l

# %%
outl_uni = (pval_univariate < epsilon_uni)
def findIndices(binVec):
    l = []
    for i in range(len(binVec)):
        if binVec[i] == 1:
            l.append(i)
    return l
listOfOutliers_uni = findIndices(outl_uni)

# %%
outl_multi = (pval_multivariate < epsilon_multi)
def findIndices(binVec):
    l = []
    for i in range(len(binVec)):
        if binVec[i] == 1:
            l.append(i)
    return l
listOfOutliers_multi = findIndices(outl_multi)

# %%
print((outl_uni==True).sum(), " ", (outl_uni==False).sum())
# Out:
# 7   300

# %%
print((outl_multi==True).sum(), " ", (outl_multi==False).sum())
# Out:
# 7   300

# %%
count_outliers = len(listOfOutliers_uni)
print('\n\nFor Univariate Number of outliers:', count_outliers)
print('\n',listOfOutliers_uni)
# Out:
# For Univariate Number of outliers: 7
#
#  [300, 301, 302, 303, 304, 305, 306]

# %%
count_outliers = len(listOfOutliers_multi)
print('\n\nFor Multivariate Number of outliers:', count_outliers)
print('\n',listOfOutliers_multi)
# Out:
# For Multivariate Number of outliers: 7
#
#  [300, 301, 302, 303, 304, 305, 306]

# %%
actualoutl = (y_val == 1)
findIndices(actualoutl)
# Out:
# [9, 49, 300, 301, 302, 303, 304, 305, 306]

# %%
#if both work in same manner, we can use any to predict for test set

plt.scatter(X[:, 0], X[:, 1], marker = "x")
plt.xlabel('X1')
plt.ylabel('X2')
plt.scatter(X[listOfOutliers_uni,0], X[listOfOutliers_uni, 1], facecolors = 'none', edgecolors = 'r')
plt.show()

# %% [markdown]
# Finally for the Test Set Prediction:

# %%
newDataset = sio.loadmat('anomalyDataTest.mat')

Xtest = newDataset['Xval']
ytest = newDataset['yval']

# %%
mutest, sigma2test = estimate_Gaussian(Xtest)
ptest = estimate_I_univariate_Probability(Xtest, mutest, sigma2test)

F1test, epsilontest = selectThreshHold(ytest, ptest)
print('\nBest epsilon and F1 are\n',epsilontest, F1test)
# Out:
# Warning dividing by zero!!
#
# Best epsilon and F1 are
#  1.6620587111948498e-18 0.6153846153846154

# %%
outliersTest = ptest < epsilontest
listOfOl = findIndices(outliersTest)

print('\n\nExpected Outliers are:\n',listOfOl)
print('\n\nNumber of outliers are: ',len(listOfOl))
# Out:
# Expected Outliers are:
#  [0, 3, 6, 11, 19, 27, 34, 43, 50, 59, 60, 69, 71, 86, 88, 92]
#
#
# Number of outliers are:  16

# %%
actualoutl = (ytest == 1)
list_Of_Ol = findIndices(actualoutl)

print('\n\nActual Outliers are:\n',list_Of_Ol)
print('\n\nNumber of outliers are: ',len(list_Of_Ol))
# Out:
# Actual Outliers are:
#  [0, 3, 19, 27, 38, 59, 71, 88, 91, 92]
#
#
# Number of outliers are:  10
